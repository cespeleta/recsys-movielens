# %%
from pathlib import Path

from src.plotting.plot_csv_logger import plot_csv_logger

# %%
path_logs = Path("../logs/MatrixFactorization/version_2")
csv_path = path_logs / "metrics.csv"

# %%
metrics = plot_csv_logger(csv_path=csv_path, eval_names=["train_mae", "valid_mae"])

# %%
metrics.tail()
# Out:
#     train_loss  epoch         step  valid_loss  valid_mae  train_mae
# 95    0.940492     95  7088.500000    0.988499   0.988499   0.920093
# 96    0.852458     96  7167.666667    0.986683   0.986683   0.918303
# 97    0.932508     97  7237.500000    0.984982   0.984982   0.916564
# 98    0.902314     98  7316.333333    0.983313   0.983313   0.914847
# 99    0.936920     99  7386.500000    0.981672   0.981672   0.913188
